# %% [markdown]
# # Homework 3 - Questions 2 and 3
# ## Analysis of Gun Deaths and College Scorecard Data
#
# It is very interesting to see the different distributions here.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Import the data
gun_data = pd.read_csv('/Users/taylorlast/Documents/GitHub/School/Python/Advanced Statistical Programming/full_data.csv')
gun_data
# Out:
#         Unnamed: 0  year  month    intent  police sex   age  \
# 0                1  2012      1   Suicide       0   M  34.0
# 1                2  2012      1   Suicide       0   F  21.0
# 2                3  2012      1   Suicide       0   M  60.0
# 3                4  2012      2   Suicide       0   M  64.0
# 4                5  2012      2   Suicide       0   M  31.0
# ...            ...   ...    ...       ...     ...  ..   ...
# 100793      100794  2014     12  Homicide       0   M  36.0
# 100794      100795  2014     12  Homicide       0   M  19.0
# 100795      100796  2014     12  Homicide       0   M  20.0
# 100796      100797  2014     12  Homicide       0   M  22.0
# 100797      100798  2014     10  Homicide       0   M  43.0
#
#                           race  hispanic              place     education
# 0       Asian/Pacific Islander       100               Home           BA+
# 1                        White       100             Street  Some college
# ...

# %%
gun_data.race.value_counts()
# Out:
# White                             66237
# Black                             23296
# Hispanic                           9022
# Asian/Pacific Islander             1326
# Native American/Native Alaskan      917
# Name: race, dtype: int64

# %%
#Create datasets for each race and sex
white_f=gun_data[(gun_data.loc[:,'race']=='White')&(gun_data.loc[:,'sex']=="F")]
white_m=gun_data[(gun_data.loc[:,'race']=='White')&(gun_data.loc[:,'sex']=="M")]
asian_f=gun_data[(gun_data.loc[:,'race']=='Asian/Pacific Islander')&(gun_data.loc[:,'sex']=="F")]
asian_m=gun_data[(gun_data.loc[:,'race']=='Asian/Pacific Islander')&(gun_data.loc[:,'sex']=="M")]
black_f=gun_data[(gun_data.loc[:,'race']=='Black')&(gun_data.loc[:,'sex']=="F")]
black_m=gun_data[(gun_data.loc[:,'race']=='Black')&(gun_data.loc[:,'sex']=="M")]
native_f=gun_data[(gun_data.loc[:,'race']=='Native American/Native Alaskan')&(gun_data.loc[:,'sex']=="F")]
native_m=gun_data[(gun_data.loc[:,'race']=='Native American/Native Alaskan')&(gun_data.loc[:,'sex']=="M")]
hispanic_f=gun_data[(gun_data.loc[:,'race']=='Hispanic')&(gun_data.loc[:,'sex']=="F")]
hispanic_m=gun_data[(gun_data.loc[:,'race']=='Hispanic')&(gun_data.loc[:,'sex']=="M")]

# %%
intentvals = ['Homicide','Suicide','Accidental','Undetermined']
counts = gun_data.intent.value_counts()

xpos = np.arange(len(counts))

plt.style.use('fivethirtyeight')

# %%
asian_m_counts = asian_m['intent'].value_counts().reindex(index=intentvals)
asian_f_counts = asian_f['intent'].value_counts().reindex(index=intentvals)

plt.figure(figsize=(8,8))
plt.subplot(211)
plt.bar(xpos,height=asian_m_counts)
plt.title('Male Asian Gun Deaths')
plt.xticks(xpos,intentvals)

plt.subplot(212)
plt.bar(xpos,height=asian_f_counts)
plt.title('Female Asian Gun Deaths')
plt.xticks(xpos,intentvals)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb2044152d0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
white_m_counts = white_m['intent'].value_counts().reindex(index=intentvals)
white_f_counts = white_f['intent'].value_counts().reindex(index=intentvals)

plt.figure(figsize=(8,8))
plt.subplot(211)
plt.bar(xpos,height=white_m_counts)
plt.title('Male White Gun Deaths')
plt.xticks(xpos,intentvals)

plt.subplot(212)
plt.bar(xpos,height=white_f_counts)
plt.title('Female White Gun Deaths')
plt.xticks(xpos,intentvals)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb20478f5d0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
black_m_counts = black_m['intent'].value_counts().reindex(index=intentvals)
black_f_counts = black_f['intent'].value_counts().reindex(index=intentvals)

plt.figure(figsize=(8,8))
plt.subplot(211)
plt.bar(xpos,height=black_m_counts)
plt.title('Male Black Gun Deaths')
plt.xticks(xpos,intentvals)

plt.subplot(212)
plt.bar(xpos,height=black_f_counts)
plt.title('Female Black Gun Deaths')
plt.xticks(xpos,intentvals)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb2049824d0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
native_m_counts = native_m['intent'].value_counts().reindex(index=intentvals)
native_f_counts = native_f['intent'].value_counts().reindex(index=intentvals)

plt.figure(figsize=(8,8))
plt.subplot(211)
plt.bar(xpos,height=native_m_counts)
plt.title('Male Native Americans Gun Deaths')
plt.xticks(xpos,intentvals)

plt.subplot(212)
plt.bar(xpos,height=native_f_counts)
plt.title('Female Native Americans Gun Deaths')
plt.xticks(xpos,intentvals)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb204b67510>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
hispanic_m_counts = hispanic_m['intent'].value_counts().reindex(index=intentvals)
hispanic_f_counts = hispanic_f['intent'].value_counts().reindex(index=intentvals)

plt.figure(figsize=(8,8))
plt.subplot(211)
plt.bar(xpos,height=hispanic_m_counts)
plt.title('Male Hispanic Gun Deaths')
plt.xticks(xpos,intentvals)

plt.subplot(212)
plt.bar(xpos,height=hispanic_f_counts)
plt.title('Female Hispanic Gun Deaths')
plt.xticks(xpos,intentvals)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb204d532d0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
plt.figure(figsize=(10,12))

plt.subplot(211)
white_hom = gun_data[(gun_data.loc[:,'race']=='White')&(gun_data.loc[:,'intent']=="Homicide")]
plt.hist(white_hom['age'],edgecolor = 'black',bins=25)
plt.title('White homicide distribution among different ages')
plt.xlabel('Age')

plt.subplot(212)
white_sui = gun_data[(gun_data.loc[:,'race']=='White')&(gun_data.loc[:,'intent']=="Suicide")]
plt.hist(white_sui['age'],edgecolor =  'black',bins=25)
plt.title('White suicide distribution among different ages')
plt.xlabel('Age')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(10,12))

plt.subplot(211)
black_hom = gun_data[(gun_data.loc[:,'race']=='Black')&(gun_data.loc[:,'intent']=="Homicide")]
plt.hist(black_hom['age'],edgecolor = 'black',bins=25)
plt.title('Black homicide distribution among different ages')
plt.xlabel('Age')

plt.subplot(212)
black_sui = gun_data[(gun_data.loc[:,'race']=='Black')&(gun_data.loc[:,'intent']=="Suicide")]
plt.hist(black_sui['age'],edgecolor =  'black',bins=25)
plt.title('Black suicide distribution among different ages')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(10,12))

plt.subplot(211)
hispanic_hom = gun_data[(gun_data.loc[:,'race']=='Hispanic')&(gun_data.loc[:,'intent']=="Homicide")]
plt.hist(hispanic_hom['age'],edgecolor = 'black',bins=25)
plt.title('Hispanic homicide distribution among different ages')
plt.xlabel('Age')

plt.subplot(212)
hispanic_sui = gun_data[(gun_data.loc[:,'race']=='Hispanic')&(gun_data.loc[:,'intent']=="Suicide")]
plt.hist(hispanic_sui['age'],edgecolor =  'black',bins=25)
plt.title('Hispanic suicide distribution among different ages')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# # Question 2c
# **Analysis for 2a:**
# Based on the bar plots in 2a we can draw conclusions about the frequency of intent of gun death for each race and gender. The first thing that sticks out is that men have many more gun deaths than women across all levels of intent and race. This could be due to men getting into conflicts more frequently than women, and it also appears that the men suicide rate is much higher than women. Looking at intent seperated by race, we see that White and Native Americans have more suicide deaths than homicide, accidental, and undetermined deaths for both male and females. Blacks and Hispanics have more homicide deaths than suicide, accidental, and undetermined deaths for both male and females. Asians have an interesting distribution of intent: Asian *women* have a higher homicide death count than they do suicide count, while Asian men have a higher suicide death count than they do homicide count.
#
# **Analysis for 2b:**
# Based on the histograms in 2b we can draw conclusions about the age distribution of suicide and homicide deaths for Whites, Blacks, and Hispanics. Based on the data, we see that Hispanics and Blacks age distribution is skewed right, which indicates that a lot of younger people die from suicide and homicide, while for the Whites age distribtuion we see a more symmetrical distribtuion (There is still a spike for Whites around 20). The median for homicides and suicides among Black and Hispanics is around 20, while the median for Whites is a little older. The distribution that surprised me was the symmetric distribution of suicide among the White population, and the median/mean appears to be in the early 50s.

# %%
# Read in the college scorecard data
college_data = pd.read_csv('/Users/taylorlast/Documents/UGA_FourthYear/STAT_4365/MERGED2015_16_PP.csv',na_values = ['NULL','PrivacySuppressed'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,9,1729,1743) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Slicing data by CONTROL
college_data_public = college_data[college_data.loc[:,'CONTROL'] == 1] 
college_data_nonprofit = college_data[college_data.loc[:,'CONTROL'] == 2] 
college_data_profit = college_data[college_data.loc[:,'CONTROL'] == 3]

#3a
plt.figure(figsize = (10,20))

plt.subplot(311)
plt.hist(college_data_public['GRAD_DEBT_MDN'], edgecolor = 'black',bins=25)
plt.title('Median debt for students who completed a public institution')
plt.xlabel('Median Debt')

plt.subplot(312)
plt.hist(college_data_nonprofit['GRAD_DEBT_MDN'], edgecolor = 'black',bins=25)
plt.title('Median debt for students who completed a nonprofit private institution')
plt.xlabel('Median Debt')

plt.subplot(313)
plt.hist(college_data_profit['GRAD_DEBT_MDN'], edgecolor = 'black',bins=25)
plt.title('Median debt for students who completed a for-profit private institution')
plt.xlabel('Median Debt')

plt.show()

# %%
#3b
plt.figure(figsize = (10,20))

plt.subplot(311)
plt.hist(college_data_public['C200_4'], edgecolor = 'black',bins=25)
plt.title('Completion rate for stundents who completed a public institution')
plt.xlabel('Completion rate')

plt.subplot(312)
plt.hist(college_data_nonprofit['C200_4'], edgecolor = 'black',bins=25)
plt.title('Completion rate for students who completed a nonprofit private institution')
plt.xlabel('Completion rate')

plt.subplot(313)
plt.hist(college_data_profit['C200_4'], edgecolor = 'black',bins=25)
plt.title('Completion rate for students who completed a for-profit private institution')
plt.xlabel('Completion rate')
# Out:
# Text(0.5, 0, 'Completion rate')

# %%
#3c

college_data_CONTROL = college_data.groupby('CONTROL')
college_data_CONTROL[['GRAD_DEBT_MDN','C200_4']].mean()
# Out:
#          GRAD_DEBT_MDN    C200_4
# CONTROL
# 1         14318.945526  0.504290
# 2         22416.872842  0.550318
# 3         15062.949901  0.256577

# %% [markdown]
# ## Question 3d
# **Analysis of 3 a,b,c:**
# Looking at the histograms of student debt for students who graduated separated by institution type, we can see that public institution have a slightly skewed right distribution with a median between 10,000 and 15,000. For private non-profit institutions we see a strongly skewed left distribution, indicating that many students who graduated were heavily in debt. For private for-profit institutions, we see a skewed right distribution with a low median for debt among those who graduated. Looking at the distributions of completion rate by instution, we see that public and private nonprofit distributions look similar, while the private for-profit distribution is skewed right (many students didn't complete school). Based on the table, we see that private nonprofit institutions have the highest debt for students who graduated but the highest completion rate. Public institutions have the lowest debt among students and around a 50% completion rate. Private for-profit instituions have by far the lowest completion rate (~25.6%).

# %%
college_data2008 = pd.read_csv('/Users/taylorlast/Documents/UGA_FourthYear/STAT_4365/MERGED2007_08_PP.csv',na_values = ['NULL','PrivacySuppressed'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
college_data2008['student_loan_vs_earnings'] = college_data2008['DEBT_MDN']/college_data2008['MN_EARN_WNE_P10']
college_data2008_CONTROL = college_data2008.groupby('CONTROL')
college_data2008_grouped = college_data2008_CONTROL[['student_loan_vs_earnings']].mean()
college_data2008_grouped
# Out:
#          student_loan_vs_earnings
# CONTROL
# 1                        0.127224
# 2                        0.211672
# 3                        0.188383

# %%
plt.figure(figsize=(8,8))

plt.scatter(college_data2008['DEBT_MDN'].loc[college_data2008['CONTROL']==1], y = college_data2008['MN_EARN_WNE_P10'].loc[college_data2008['CONTROL']==1],color="red",label="Public")
plt.title("Median Debt vs. Earnings 10 years after graduation")
plt.xlabel("Debt of College Graduates")
plt.ylabel("Earnings 10 years after graduation" )
plt.legend(labels=["Public","Private Nonprofit","Private for Profit"])

plt.scatter(college_data2008['DEBT_MDN'].loc[college_data2008['CONTROL']==2],  y = college_data2008['MN_EARN_WNE_P10'].loc[college_data2008['CONTROL']==2], color="blue",label="Private non-profit")
plt.title("Median Debt vs. Earnings 10 years after graduation")
plt.xlabel("Debt of College Graduates")
plt.ylabel("Earnings 10 years after graduation" )
plt.legend(labels=["Public","Private Nonprofit","Private for Profit"])

plt.scatter(college_data2008['DEBT_MDN'].loc[college_data2008['CONTROL']==3],  y = college_data2008['MN_EARN_WNE_P10'].loc[college_data2008['CONTROL']==3], color="green",label="Private for-profit")
plt.title("Median Debt vs. Earnings 10 years after graduation")
plt.xlabel("Debt of College Graduates")
plt.ylabel("Earnings 10 years after graduation" )
plt.legend(labels=["Public","Private Nonprofit","Private for Profit"])

plt.legend()

# %% [markdown]
# ## Question 3e
# **Analysis of 3 e,f:**
# Based on our table of the ratio of (debt/earnings 10 years after graduation), we see that public institutions perform the best because it is the lowest, and private nonprofit institutions perform the worst since it is the highest. For every dollar made 10 years after graduation 12.7 cents were spent on debt at public institutions. Based on the plot in 3f, we see that there is a positive correlation between debt of college graduates and earnings 10 years after graduation. Private nonprofit instituion students have the highest amount of debt, but on average, it appears that those students are making the most 10 years after graduation.
